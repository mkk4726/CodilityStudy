# %%
from pathlib import Path

from src.core.testcase import load_testcases

test_cases = load_testcases(Path.cwd() / "testcases.txt")

# %%
test_cases
# Out:
# [TestCase(name='example1', input={'string_list': ['apple', 'banna', 'cherry'], 'query_list': ['banna', 'kiwi', 'melon', 'apple']}, expected=[True, False, False, True]),
#  TestCase(name='all_found', input={'string_list': ['apple', 'banana'], 'query_list': ['apple', 'banana']}, expected=[True, True]),
#  TestCase(name='none_found', input={'string_list': ['apple', 'banana'], 'query_list': ['kiwi', 'melon']}, expected=[False, False]),
#  TestCase(name='single_found', input={'string_list': ['a'], 'query_list': ['a']}, expected=[True]),
#  TestCase(name='single_not_found', input={'string_list': ['a'], 'query_list': ['b']}, expected=[False]),
#  TestCase(name='prefix_is_not_match', input={'string_list': ['apple'], 'query_list': ['app', 'apple', 'apples']}, expected=[False, True, False]),
#  TestCase(name='anagram_is_not_match', input={'string_list': ['abc'], 'query_list': ['cba', 'bac', 'abc']}, expected=[False, False, True]),
#  TestCase(name='duplicate_query', input={'string_list': ['cat'], 'query_list': ['cat', 'cat', 'dog']}, expected=[True, True, False]),
#  TestCase(name='empty_query_list', input={'string_list': ['apple'], 'query_list': []}, expected=[]),
#  TestCase(name='empty_string_list', input={'string_list': [], 'query_list': ['apple', 'banana']}, expected=[False, False])]

# %%
example1 = test_cases[0]

string_list, query_list = example1.input.values()

# %%
string_list
# Out:
# ['apple', 'banna', 'cherry']

# %%
query_list
# Out:
# ['banna', 'kiwi', 'melon', 'apple']

# %%
def hash(s: str):
    p = 31
    m = 1000000007

    hash_result = 0
    for i in range(len(s)):
        hash_result += s[i] * (p**i)
    
    return hash_result % m

# %%
string_hash = {}
for string in string_list:
