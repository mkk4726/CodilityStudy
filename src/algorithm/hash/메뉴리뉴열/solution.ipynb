# %%
from pathlib import Path

from src.core.testcase import load_testcases, run_testcases
from solution import solution

test_cases = load_testcases(Path.cwd() / "testcases.txt")

# %%
test_cases
# Out:
# [TestCase(name='example1', input={'orders': ['ABCFG', 'AC', 'CDE', 'ACDE', 'BCFG', 'ACDEH'], 'course': [2, 3, 4]}, expected=['AC', 'ACDE', 'BCFG', 'CDE']),
#  TestCase(name='example2', input={'orders': ['ABCDE', 'AB', 'CD', 'ADE', 'XYZ', 'XYZ', 'ACD'], 'course': [2, 3, 5]}, expected=['ACD', 'AD', 'ADE', 'CD', 'XYZ']),
#  TestCase(name='example3', input={'orders': ['XYZ', 'XWY', 'WXA'], 'course': [2, 3, 4]}, expected=['WX', 'XY']),
#  TestCase(name='unsorted_letters', input={'orders': ['BA', 'AB'], 'course': [2]}, expected=['AB']),
#  TestCase(name='two_identical_orders', input={'orders': ['ABC', 'ABC'], 'course': [2, 3]}, expected=['AB', 'ABC', 'AC', 'BC']),
#  TestCase(name='only_pairs', input={'orders': ['ABCFG', 'AC', 'CDE', 'ACDE', 'BCFG', 'ACDEH'], 'course': [2]}, expected=['AC']),
#  TestCase(name='tie_two_pairs', input={'orders': ['AB', 'AC', 'BC', 'AB', 'AC'], 'course': [2]}, expected=['AB', 'AC']),
#  TestCase(name='shared_triple', input={'orders': ['ABCD', 'ABCE'], 'course': [3]}, expected=['ABC'])]

# %%
example1 = test_cases[0]

# %%
example1
# Out:
# TestCase(name='example1', input={'orders': ['ABCFG', 'AC', 'CDE', 'ACDE', 'BCFG', 'ACDEH'], 'course': [2, 3, 4]}, expected=['AC', 'ACDE', 'BCFG', 'CDE'])

# %%
orders, course = example1.input.values()
orders, course
# Out:
# (['ABCFG', 'AC', 'CDE', 'ACDE', 'BCFG', 'ACDEH'], [2, 3, 4])

# %%
# O(N * 2^M) 시간복잡도인거보면 조합을 추출하는 건 맞는 것 같은데
# 진짜 감이 아예 안오네?
# 5분만 더 생각해보자.
# 어캐 풀 수 있을까?
# 조합에 대한 해시를 구성한다. 아니 그냥 조합의 수를 센다?



orders
# Out:
# ['ABCFG', 'AC', 'CDE', 'ACDE', 'BCFG', 'ACDEH']

# %%
# 2개조합 어떻게 구하지?
# Out:
# 'ABCFG'

# %%
# orders로부터 조합의 개수를 셀 필요가 있겠네
# 조합의 개수를 어떻게 셀 수 있지?

# %%
# Out:
# ABCFG
# AC
# CDE
# ACDE
# BCFG
# ACDEH

# %%
list('ACDEH')
# Out:
# ['A', 'C', 'D', 'E', 'H']

# %%
a = set("ABCFG")
b = set("AC")
c = set("CDE")

# %%
a & b
# Out:
# {'A', 'C'}

# %%
a & c
# Out:
# {'C'}

# %%
results = run_testcases(solution, test_cases)
results
# Out:
# [TestResult(case=TestCase(name='example1', input={'orders': ['ABCFG', 'AC', 'CDE', 'ACDE', 'BCFG', 'ACDEH'], 'course': [2, 3, 4]}, expected=['AC', 'ACDE', 'BCFG', 'CDE']), actual=None, passed=False),
#  TestResult(case=TestCase(name='example2', input={'orders': ['ABCDE', 'AB', 'CD', 'ADE', 'XYZ', 'XYZ', 'ACD'], 'course': [2, 3, 5]}, expected=['ACD', 'AD', 'ADE', 'CD', 'XYZ']), actual=None, passed=False),
#  TestResult(case=TestCase(name='example3', input={'orders': ['XYZ', 'XWY', 'WXA'], 'course': [2, 3, 4]}, expected=['WX', 'XY']), actual=None, passed=False),
#  TestResult(case=TestCase(name='unsorted_letters', input={'orders': ['BA', 'AB'], 'course': [2]}, expected=['AB']), actual=None, passed=False),
#  TestResult(case=TestCase(name='two_identical_orders', input={'orders': ['ABC', 'ABC'], 'course': [2, 3]}, expected=['AB', 'ABC', 'AC', 'BC']), actual=None, passed=False),
#  TestResult(case=TestCase(name='only_pairs', input={'orders': ['ABCFG', 'AC', 'CDE', 'ACDE', 'BCFG', 'ACDEH'], 'course': [2]}, expected=['AC']), actual=None, passed=False),
#  TestResult(case=TestCase(name='tie_two_pairs', input={'orders': ['AB', 'AC', 'BC', 'AB', 'AC'], 'course': [2]}, expected=['AB', 'AC']), actual=None, passed=False),
#  TestResult(case=TestCase(name='shared_triple', input={'orders': ['ABCD', 'ABCE'], 'course': [3]}, expected=['ABC']), actual=None, passed=False)]
