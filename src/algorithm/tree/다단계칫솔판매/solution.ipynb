# %%
from pathlib import Path
from src.core.testcase import load_testcases, run_testcases
from solution import solution

test_cases = load_testcases(Path.cwd() / "testcases.txt")
results = run_testcases(solution, test_cases)

# %%
test_cases
# Out:
# [TestCase(name='example1', input={'enroll': ['john', 'mary', 'edward', 'sam', 'emily', 'jaimie', 'tod', 'young'], 'referral': ['-', '-', 'mary', 'edward', 'mary', 'mary', 'jaimie', 'edward'], 'seller': ['young', 'john', 'tod', 'emily', 'mary'], 'amount': [12, 4, 2, 5, 10]}, expected=[360, 958, 108, 0, 450, 18, 180, 1080]),
#  TestCase(name='example2', input={'enroll': ['john', 'mary', 'edward', 'sam', 'emily', 'jaimie', 'tod', 'young'], 'referral': ['-', '-', 'mary', 'edward', 'mary', 'mary', 'jaimie', 'edward'], 'seller': ['sam', 'emily', 'jaimie', 'edward'], 'amount': [2, 3, 5, 4]}, expected=[0, 110, 378, 180, 270, 450, 0, 0]),
#  TestCase(name='single_seller', input={'enroll': ['a'], 'referral': ['-'], 'seller': ['a'], 'amount': [1]}, expected=[90]),
#  TestCase(name='max_amount', input={'enroll': ['a'], 'referral': ['-'], 'seller': ['a'], 'amount': [100]}, expected=[9000]),
#  TestCase(name='same_seller_twice', input={'enroll': ['a'], 'referral': ['-'], 'seller': ['a', 'a'], 'amount': [1, 1]}, expected=[180]),
#  TestCase(name='no_sales', input={'enroll': ['a', 'b'], 'referral': ['-', 'a'], 'seller': ['a'], 'amount': [1]}, expected=[90, 0]),
#  TestCase(name='chain_truncation', input={'enroll': ['a', 'b', 'c'], 'referral': ['-', 'a', 'b'], 'seller': ['c'], 'amount': [1]}, expected=[1, 9, 90]),
#  TestCase(name='deep_chain_stops', input={'enroll': ['a', 'b', 'c', 'd'], 'referral': ['-', 'a', 'b', 'c'], 'seller': ['d'], 'amount': [1]}, expected=[0, 1, 9, 90]),
#  TestCase(name='two_direct_to_center', input={'enroll': ['john', 'mary'], 'referral': ['-', '-'], 'seller': ['john', 'mary'], 'amount': [4, 10]}, expected=[360, 900]),
#  TestCase(name='middle_sells_and_receives', input={'enroll': ['a', 'b'], 'referral': ['-', 'a'], 'seller': ['b', 'a'], 'amount': [1, 1]}, expected=[99, 90])]

# %%
# 트리 쪽 확실히 잘 안풀리네
# 이런 문제를 보면 이진트리를 그래서 구현해야하는건가? 라는 생각이 듬
