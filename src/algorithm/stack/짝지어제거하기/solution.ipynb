# %%
from pathlib import Path

from src.core.testcase import load_testcases

test_cases = load_testcases(Path.cwd() / "testcases.txt")

# %%
test_cases
# Out:
# [TestCase(name='example_success', input={'s': 'baabaa'}, expected=True),
#  TestCase(name='example_fail', input={'s': 'cdcd'}, expected=False),
#  TestCase(name='single_char', input={'s': 'a'}, expected=False),
#  TestCase(name='double_same', input={'s': 'aa'}, expected=True),
#  TestCase(name='double_diff', input={'s': 'ab'}, expected=False),
#  TestCase(name='nested_pairs', input={'s': 'abccba'}, expected=True),
#  TestCase(name='sequential_pairs', input={'s': 'aabbcc'}, expected=True),
#  TestCase(name='odd_length', input={'s': 'aabbc'}, expected=False),
#  TestCase(name='no_adjacent_repeat', input={'s': 'abcabc'}, expected=False),
#  TestCase(name='large_no_match', input={'s': 'abababababababababababababababababababababababababababababababababababababababababababababababab'}, expected=False),
#  TestCase(name='large_all_match', input={'s': 'aabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabbaabb'}, expected=True)]

# %%
example_success = test_cases[0].input
s = example_success['s']

# %%
def delete_dups(s:str) -> str | bool:
    for i in range(len(s)-1):
        if s[i] == s[i+1]:
            return s[:i] + s[i+2:]
    
    return False

# %%
"baabaa"

# stack으로 풀면 더 쉽게 풀 수 있다고?
# Out:
# 'baabaa'

# %%
stack = []

stack.append(1)
stack.pop()
# Out:
# 1

# %%
while s:
    s = delete_dups(s)

# %%
int(s=="1")
# Out:
# 0

# %%
stack = []

for alphabet in s:
    if len(stack) > 0:
        before_alphabet = stack.pop()
        if before_alphabet == alphabet:
            continue
        else:
            stack.append(before_alphabet)
            stack.append(alphabet)

stack
# Out:
# []
